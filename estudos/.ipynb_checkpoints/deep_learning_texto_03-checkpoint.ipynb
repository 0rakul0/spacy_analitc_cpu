# %% [markdown]
# #### algumas coisas que é bom lembrar
# - loss: Função de perda, para avaliar o erro, normalmente usamo o MSE( media do erro quadratico )
# - optmizer: Otimizador de ajuste dos pesos da Rede, no caso o ADAM é ( gradiente decendente estocastico )
# - metrics: A metrica que a rede vai utilizar para avaliar a performance

# %%
# !pip install pandas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
# !python --version
# Out:
# Python 3.7.1

# %%
try:
    import tensorflow as tf
except:
    # !pip install tensorflow-gpu==2.6
    import tensorflow as tf

# %%
try:
    import keras
except:
    # !pip install keras
    import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding
from keras.preprocessing.text import Tokenizer
from keras. import pad_sequences
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\jefferson\AppData\Local\Temp\ipykernel_7420\2066917518.py", line 4, in <module>
#     from keras.preprocessing.text import pad_sequences
# ImportError: cannot import name 'pad_sequences' from 'keras.preprocessing.text' (C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\keras\preprocessing\text.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 1500, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 1458, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# ERROR! Session/line number was not unique in database. History logging moved to new session 49
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\jefferson\AppData\Local\Temp\ipykernel_7420\2066917518.py", line 4, in <module>
#     from keras.preprocessing.text import pad_sequences
# ImportError: cannot import name 'pad_sequences' from 'keras.preprocessing.text' (C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\keras\preprocessing\text.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 1500, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 1458, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\jefferson\AppData\Local\Temp\ipykernel_7420\2066917518.py", line 4, in <module>
#     from keras.preprocessing.text import pad_sequences
# ImportError: cannot import name 'pad_sequences' from 'keras.preprocessing.text' (C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\keras\preprocessing\text.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 1500, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 1458, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\jefferson\.conda\envs\gpu\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
dataset = pd.read_csv('../dados/spam/spam.csv')
dataset.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # tratamento de dados
# ### aqui é um problema de classificação se é ou não SPAM
# ### transforma em numeros

# %% [markdown]
# ### transforma as respostas

# %%
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(dataset['Category'])

# %% [markdown]
# ### pega os textos

# %%
mensagens = dataset['Message'].values

# %% [markdown]
# ### separa em treino e teste

# %%
X_traino, X_teste, y_treino, y_teste = train_test_split(mensagens, y, test_size=0.3)

# %% [markdown]
# ### embedding dos textos

# %%
token = Tokenizer(num_words=1000)
token.fit_on_texts(X_traino)

# %%
X_traino = token.texts_to_sequences(X_traino)
X_teste = token.texts_to_sequences(X_teste)

# %% [markdown]
# ### O que é feito aqui é um seguinte, é uma lista que quando a palavra aparece no indice ele marca como 1

# %%
print(X_traino)
# Out:
# [[195, 16, 48, 13, 357, 13, 857, 42, 283, 24, 457, 382, 152, 637, 503, 573, 161, 284, 421, 358, 858, 278], [149, 1, 67, 3], [1, 422, 20, 174, 75, 49, 608, 423, 4, 638, 19, 87, 441, 51, 75, 49, 66, 20, 932, 608, 24, 19, 14], [1, 56, 3, 158, 125, 25, 57, 158, 402], [33, 13, 285, 11, 933, 34, 4, 43, 15, 933, 7, 535, 249, 71, 34, 5, 39, 934, 2, 85, 240, 203], [574, 56, 292, 286], [51, 241, 424, 14, 97, 2, 33, 2, 5, 15, 4], [145, 39, 293, 1, 70, 3, 168, 1, 82, 3, 859, 12, 344, 34, 13, 67, 39, 2, 777, 262, 250, 168, 6, 146, 141, 27, 14, 102, 102, 27, 14], [147, 294, 6, 16, 19, 13, 295], [575, 639, 681], [45, 44, 383, 60, 217, 383, 935], [28, 27, 3, 222, 30, 29, 49, 114, 1, 345, 30, 536, 2, 33, 52, 15, 126, 4, 425, 359], [78, 275, 65, 32, 3, 640, 682, 3, 28, 33, 14, 188, 17, 4, 279], [6, 53, 51, 2, 576, 11, 4, 641, 9, 12, 641], [3, 17, 72, 722, 9, 29, 171, 7, 860, 45, 44, 2, 778, 15, 27, 26, 24, 2, 683], [8, 142, 61, 287, 15, 485, 7, 8, 
[1, 252, 183, 5, 110, 144, 18, 102, 67, 4, 151], [36, 87, 1, 57, 115, 21, 40, 492], [311, 75, 26, 868], [22, 6, 8, 65, 731, 65], [38, 539, 7], [464, 464, 325, 6, 130, 302, 89, 162, 206, 1, 687, 6], [104, 257, 2, 326, 387, 88, 25, 78, 337, 79], [540], [19, 4, 114, 81, 6, 42, 338], [84, 93, 16, 108], [28, 3, 56, 2, 30], [493, 270, 7, 869, 42, 43, 19, 339, 613, 19, 175, 790, 732, 16, 614, 19, 688, 24, 870], [23, 423, 4, 687, 21, 646, 34, 5, 360, 148, 65, 23, 111, 31, 541, 647], [1, 117, 22, 3, 1, 17, 2, 50, 7, 12, 271, 29, 217], [112, 122, 1, 465, 120, 130, 23, 21, 40, 31, 304], [134, 1, 109, 23, 1, 57, 9, 375, 25, 12, 8, 9, 428, 1, ...

# %% [markdown]
# ### com este metodo precisamos dá a todas as linhas o mesmo tamanho usando o pad

# %%
tamanho_maximo = 500

# %%
X_traino = pad_sequences(X_traino, padding="post", maxlen=tamanho_maximo) # coloca a direta [2,5,8,2,0,0,0,0,0]
X_teste = pad_sequences(X_teste, padding="post", maxlen=tamanho_maximo) # coloca a direta [2,5,8,2,0,0,0,0,0]

# %%
print(X_traino)
# Out:
# [[195  16  48 ...   0   0   0]
#  [149   1  67 ...   0   0   0]
#  [  1 422  20 ...   0   0   0]
#  ...
#  [  6   6 155 ...   0   0   0]
#  [126  57  62 ...   0   0   0]
#  [ 36 347  40 ...   0   0   0]]

# %% [markdown]
# ### para ver a quantidade de palavras diferentes

# %%
print(len(token.word_index))
# Out:
# 7382

# %% [markdown]
# ### iniciando o modelo

# %%
modelo = Sequential()

# %% [markdown]
# ### adicionando uma camada embadding

# %%
modelo.add(Embedding(input_dim=len(token.word_index), output_dim=50, input_length=tamanho_maximo))

# %%
modelo.add(Flatten())

# %% [markdown]
# ### camadas densas

# %%
modelo.add(Dense(units=10, activation="relu"))
modelo.add(Dropout(0.1))
modelo.add(Dense(units=1, activation="sigmoid"))

# %% [markdown]
# ### após o modelo criado precisamos compilar o modelo

# %%
modelo.compile(loss="mean_squared_error", optimizer="adam", metrics=["accuracy"])

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 50)           369100
#
#  flatten (Flatten)           (None, 25000)             0
#
#  dense (Dense)               (None, 10)                250010
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 619,121
# Trainable params: 619,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# treinando o modelo

# %%
modelo.fit(X_traino, y_treino, epochs=40, batch_size=15, verbose=True, validation_data=(X_teste, y_teste))
# Out:
# Epoch 1/40
# 260/260 [==============================] - 3s 8ms/step - loss: 0.0771 - accuracy: 0.9133 - val_loss: 0.0385 - val_accuracy: 0.9707
# Epoch 2/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0380 - accuracy: 0.9831 - val_loss: 0.0305 - val_accuracy: 0.9880
# Epoch 3/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 0.0264 - val_accuracy: 0.9856
# Epoch 4/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.0229 - val_accuracy: 0.9868
# Epoch 5/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.0200 - val_accuracy: 0.9880
# Epoch 6/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9962 - val_loss: 0.0187 - val_accuracy: 0.9862
# Epoch 7/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.0169 - val_accuracy: 0.9886
# Epoch 8/40
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0158 - val_accuracy: 0.9874
# Epoch 9/40
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0156 - val_accuracy: 0.9868
# Epoch 10/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0143 - val_accuracy: 0.9874
# Epoch 11/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0129 - val_accuracy: 0.9886
# Epoch 12/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0123 - val_accuracy: 0.9886
# Epoch 13/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0122 - val_accuracy: 0.9886
# Epoch 14/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0036 - accuracy: 0.9982 - val_loss: 0.0115 - val_accuracy: 0.9874
# Epoch 15/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0020 - accuracy: 0.9982 - val_loss: 0.0102 - val_accuracy: 0.9880
# Epoch 16/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0019 - accuracy: 0.9982 - val_loss: 0.0119 - val_accuracy: 0.9874
# Epoch 17/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0020 - accuracy: 0.9979 - val_loss: 0.0111 - val_accuracy: 0.9880
# Epoch 18/40
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0018 - accuracy: 0.9982 - val_loss: 0.0111 - val_accuracy: 0.9886
# Epoch 19/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0019 - accuracy: 0.9982 - val_loss: 0.0110 - val_accuracy: 0.9874
# Epoch 20/40
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0018 - accuracy: 0.9982 - val_loss: 0.0112 - val_accuracy: 0.9880
# Epoch 21/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0018 - accuracy: 0.9982 - val_loss: 0.0134 - val_accuracy: 0.9844
# Epoch 22/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0017 - accuracy: 0.9979 - val_loss: 0.0142 - val_accuracy: 0.9839
# Epoch 23/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0019 - accuracy: 0.9979 - val_loss: 0.0136 - val_accuracy: 0.9844
# Epoch 24/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0016 - accuracy: 0.9982 - val_loss: 0.0132 - val_accuracy: 0.9844
# Epoch 25/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0025 - accuracy: 0.9967 - val_loss: 0.0265 - val_accuracy: 0.9689
# Epoch 26/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0016 - accuracy: 0.9985 - val_loss: 0.0166 - val_accuracy: 0.9821
# Epoch 27/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0027 - accuracy: 0.9969 - val_loss: 0.0244 - val_accuracy: 0.9725
# Epoch 28/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0022 - accuracy: 0.9977 - val_loss: 0.0121 - val_accuracy: 0.9862
# Epoch 29/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0015 - accuracy: 0.9985 - val_loss: 0.0126 - val_accuracy: 0.9856
# Epoch 30/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0016 - accuracy: 0.9982 - val_loss: 0.0135 - val_accuracy: 0.9850
# Epoch 31/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0015 - accuracy: 0.9982 - val_loss: 0.0136 - val_accuracy: 0.9844
# Epoch 32/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0016 - accuracy: 0.9985 - val_loss: 0.0128 - val_accuracy: 0.9862
# Epoch 33/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0016 - accuracy: 0.9985 - val_loss: 0.0145 - val_accuracy: 0.9839
# Epoch 34/40
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0018 - accuracy: 0.9977 - val_loss: 0.0130 - val_accuracy: 0.9844
# Epoch 35/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0015 - accuracy: 0.9985 - val_loss: 0.0131 - val_accuracy: 0.9868
# Epoch 36/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0015 - accuracy: 0.9985 - val_loss: 0.0139 - val_accuracy: 0.9839
# Epoch 37/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0017 - accuracy: 0.9979 - val_loss: 0.0146 - val_accuracy: 0.9839
# Epoch 38/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0015 - accuracy: 0.9985 - val_loss: 0.0132 - val_accuracy: 0.9856
# Epoch 39/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0019 - accuracy: 0.9979 - val_loss: 0.0128 - val_accuracy: 0.9856
# Epoch 40/40
# 260/260 [==============================] - 2s 7ms/step - loss: 0.0015 - accuracy: 0.9982 - val_loss: 0.0136 - val_accuracy: 0.9844

# %% [markdown]
# #### para avaliação do modelo

# %%
loss, accuracy = modelo.evaluate(X_teste, y_teste)
print(f"loss: {loss}\n accuracy: {accuracy}")
# Out:
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9844
# loss: 0.013571429066359997
#  accuracy: 0.9844497442245483

# %%
nova_previsao = modelo.predict(X_teste)
e_spam = (nova_previsao>0.7)
print(e_spam)
# Out:
# 53/53 [==============================] - 0s 2ms/step
# [[False]
#  [False]
#  [ True]
#  ...
#  [False]
#  [ True]
#  [False]]

# %% [markdown]
# ### matriz de confusao

# %%
cm = confusion_matrix(y_teste, e_spam)
print(cm)
# Out:
# [[1451    9]
#  [  16  196]]

# %%
modelo.save("../modelo.h5")

# %% [markdown]
# # tipos de embedding
# - input_dim = Tamanho de entradas do vocabulo
# - output_dim = Tamanho do vetor denso
# - input_length = tamanho maximo da sequência
#
# ## para imagens
# - camada Embedding devem ser conectadas a uma camada Flatten
# - camada Flatten conectada a Densa
